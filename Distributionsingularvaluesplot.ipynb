# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
T=500
Nx=1000
Ny=1000
P=np.random.normal(0,1,size=(T,Nx))
Pt=np.transpose(P)
A=np.matmul(P,Pt)
Qx=np.random.normal(0,1,size=(T,Ny))
Qxt=np.transpose(Qx)
A1=np.matmul(Qx,Qxt)
B=np.matmul(A,A1)
B1=np.multiply(B,1/(T*T))
w,v=np.linalg.eig(B1)


W1=w
for i in range(500):
    P=np.random.normal(0,1,size=(T,Nx))
    Pt=np.transpose(P)
    A=np.matmul(P,Pt)
    Qx=np.random.normal(0,1,size=(T,Ny))
    Qxt=np.transpose(Qx)
    A1=np.matmul(Qx,Qxt)
    B=np.matmul(A,A1)
    B1=np.multiply(B,1/(T*T))
    w,v=np.linalg.eig(B1)
    W2=np.hstack((W1, w))
    W1=W2
    W1pro=W1
plt.hist(W1, histtype='bar', density=True, bins=20, color = "skyblue")
print(len(W1))
np.savetxt('simpurenoise0.txt', W1pro, delimiter=' ')   # X is an array
plt.show()
# Out:
# 250500

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
T=500
Nx=50000
Ny=50000
P=np.random.normal(0,1,size=(T,Nx))
Pt=np.transpose(P)
A=np.matmul(P,Pt)
Qx=np.random.normal(0,1,size=(T,Ny))
Qxt=np.transpose(Qx)
A1=np.matmul(Qx,Qxt)
B=np.matmul(A,A1)
B1=np.multiply(B,1/(T*T))
w,v=np.linalg.eig(B1)


W1=w
for i in range(500):
    P=np.random.normal(0,1,size=(T,Nx))
    Pt=np.transpose(P)
    A=np.matmul(P,Pt)
    Qx=np.random.normal(0,1,size=(T,Ny))
    Qxt=np.transpose(Qx)
    A1=np.matmul(Qx,Qxt)
    B=np.matmul(A,A1)
    B1=np.multiply(B,1/(T*T))
    w,v=np.linalg.eig(B1)
    W2=np.hstack((W1, w))
    W1=W2
    W1pro=W1
plt.hist(W1, histtype='bar', density=True, bins=20, color = "skyblue")
print(len(W1))
np.savetxt('simpurenoise1.txt', W1pro, delimiter=' ')   # X is an array
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
T=500
Nx=1000
Ny=50000
P=np.random.normal(0,1,size=(T,Nx))
Pt=np.transpose(P)
A=np.matmul(P,Pt)
Qx=np.random.normal(0,1,size=(T,Ny))
Qxt=np.transpose(Qx)
A1=np.matmul(Qx,Qxt)
B=np.matmul(A,A1)
B1=np.multiply(B,1/(T*T))
w,v=np.linalg.eig(B1)


W1=w
for i in range(500):
    P=np.random.normal(0,1,size=(T,Nx))
    Pt=np.transpose(P)
    A=np.matmul(P,Pt)
    Qx=np.random.normal(0,1,size=(T,Ny))
    Qxt=np.transpose(Qx)
    A1=np.matmul(Qx,Qxt)
    B=np.matmul(A,A1)
    B1=np.multiply(B,1/(T*T))
    w,v=np.linalg.eig(B1)
    W2=np.hstack((W1, w))
    W1=W2
    W1pro=W1
plt.hist(W1, histtype='bar', density=True, bins=20, color = "skyblue")
print(len(W1))
np.savetxt('simpurenoise3.txt', W1pro, delimiter=' ')   # X is an array
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
T=100
Nx=100
Ny=3000
P=np.random.normal(0,1,size=(T,Nx))
Pt=np.transpose(P)
A=np.matmul(P,Pt)
Qx=np.random.normal(0,1,size=(T,Ny))
Qxt=np.transpose(Qx)
A1=np.matmul(Qx,Qxt)
B=np.matmul(A,A1)
B1=np.multiply(B,1/(T*T))
w,v=np.linalg.eig(B1)


W1=w
for i in range(500):
    P=np.random.normal(0,1,size=(T,Nx))
    Pt=np.transpose(P)
    A=np.matmul(P,Pt)
    Qx=np.random.normal(0,1,size=(T,Ny))
    Qxt=np.transpose(Qx)
    A1=np.matmul(Qx,Qxt)
    B=np.matmul(A,A1)
    B1=np.multiply(B,1/(T*T))
    w,v=np.linalg.eig(B1)
    W2=np.hstack((W1, w))
    W1=W2
    W1pro=W1
plt.hist(W1, histtype='bar', density=True, bins=20, color = "skyblue")
print(len(W1))
np.savetxt('simpurenoise4.txt', W1pro, delimiter=' ')   # X is an array
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(12,12))
T=100
Nx=200
Ny=200
W1pro1= np.loadtxt('simpurenoise0.txt', delimiter=" ")
W1pro= np.loadtxt('simpurenoise0.txt', delimiter=" ")
import numpy as np
import matplotlib.pyplot as plt
from sympy import roots
from sympy import var
from sympy import re, im, I, E, symbols
import numpy as np
import sympy as sym
from math import sqrt
from sympy.abc import g

q=Nx/Ny
qU=T/Nx
qv=T/Ny

xB=[]
y2B=[]
yimgB=[]
yrealB=[]
for i in range (10,2000):
    a1=i*0.01-I*0.0001
    a1inot=i*0.01
    a13=a1**2*qU*qv
    a12=(qv*(1-qU)+qU*(1-qv))*a1
    a11=((1-qU)*(1-qv))-a1*qU*qv
    a10=qU*qv
    xB.append(a1inot)
    ysols=[]
    ysols1=[]
    a=roots(a13*g**3+a12*g**2+a11*g+a10,g)
    value=[im(j) for j in a if a[j]==int(1)]
    result = a.items()
    data = list(result)
    for i in range(len(data)):
        a1=complex(data[i][0])
        a1r=a1.real/(3.14)
        a1img=a1.imag/(3.14)
        ysols.append(a1img)
        ysols1.append(a1.real)
    yimgB.append(ysols)
    yrealB.append(ysols1)

print('done')
ydata=[]
for i in range (len(xB)):
    ydata.append(abs(yimgB[i][1]))
xB=np.array(xB)
a11=np.sqrt(qU*qv)
qx=qU
y1=(8*qx**2 + 20*qx**3 - qx**4 - qx**(5/2)*(8 + qx)**(3/2))/(8*qx**4)
y2=(8*qx**2 + 20*qx**3 - qx**4 + qx**(5/2)*(8 + qx)**(3/2))/(8*qx**4)
ydataB=np.array(ydata)
y11=math.sqrt(y1)
y21=math.sqrt(y2)
xB=np.array(xB)
xB1=np.sqrt(xB)
W1pro1=np.sqrt(W1pro)
ydataB=np.array(ydata)
ydataB1=np.multiply(xB1,ydata)
ax1.plot(xB1*a11,2*ydataB1/(a11), linewidth=3.0, color='#f781bf', label='Semi-Analytic')
ax1.hist(W1pro1*a11, histtype='bar', density=True, bins=200,  color = "#377eb8" ,label='Simulation')
ax1.axvline(x=y11*a11, color='black', linewidth=3.0, linestyle='--',label= 'Analytic bounds')
ax1.axvline(x=y21*a11, color='black',linewidth=3.0,linestyle='--')
ax1.set_xlabel(r'$\gamma \sqrt{p_X p_Y}$', fontsize=24)
ax1.set_ylabel(r'$\rho(\gamma)/\sqrt{p_X p_Y}$', fontsize=24)
ax1.tick_params(labelsize=16)
ax1.set_xlim(0,2.4)
ax1.legend(title=r'$p_X=p_Y=0.5$', framealpha=0.5, fontsize=16, title_fontsize=20,loc=1)
ax1.annotate('(a)', xy=(0, 1), xycoords='axes fraction', fontsize=24,
                xytext=(-25,25), textcoords='offset points',
                ha='right', va='top')


T=500
Nx=50000
Ny=50000
W1pro1= np.loadtxt('simpurenoise1.txt', delimiter=" ")
W1pro= np.loadtxt('simpurenoise1.txt', delimiter=" ")
import numpy as np
import matplotlib.pyplot as plt
from sympy import roots
from sympy import var
from sympy import re, im, I, E, symbols
import numpy as np
import sympy as sym
from math import sqrt
from sympy.abc import g

q=Nx/Ny
qU=T/Nx
qv=T/Ny

xB=[]
y2B=[]
yimgB=[]
yrealB=[]
for i in range (700, 1400):
    a1=i*10-I*0.0001
    a1inot=i*10
    a13=a1**2*qU*qv
    a12=(qv*(1-qU)+qU*(1-qv))*a1
    a11=((1-qU)*(1-qv))-a1*qU*qv
    a10=qU*qv
    xB.append(a1inot)
    ysols=[]
    ysols1=[]
    a=roots(a13*g**3+a12*g**2+a11*g+a10,g)
    value=[im(j) for j in a if a[j]==int(1)]
    result = a.items()
    data = list(result)
    for i in range(len(data)):
        a1=complex(data[i][0])
        a1r=a1.real/(3.14)
        a1img=a1.imag/(3.14)
        ysols.append(a1img)
        ysols1.append(a1.real)
    yimgB.append(ysols)
    yrealB.append(ysols1)

print('done')
ydata=[]
for i in range (len(xB)):
    ydata.append(abs(yimgB[i][1]))
xB=np.array(xB)
a11=np.sqrt(qU*qv)
qx=qU
y1=(8*qx**2 + 20*qx**3 - qx**4 - qx**(5/2)*(8 + qx)**(3/2))/(8*qx**4)
y2=(8*qx**2 + 20*qx**3 - qx**4 + qx**(5/2)*(8 + qx)**(3/2))/(8*qx**4)
ydataB=np.array(ydata)
y11=math.sqrt(y1)
y21=math.sqrt(y2)
xB=np.array(xB)
xB1=np.sqrt(xB)
W1pro1=np.sqrt(W1pro)
ydataB=np.array(ydata)
ydataB1=np.multiply(xB1,ydata)
ax2.plot(xB1*a11,2*ydataB1/(a11), linewidth=3.0, color='#f781bf', label='Semi-Analytic')
ax2.hist(W1pro1*a11, histtype='bar', density=True, bins=200,  color = "#377eb8" ,label='Simulation')
ax2.axvline(x=y11*a11, color='black', linewidth=3.0, linestyle='--',label= 'Analytic bounds')
ax2.axvline(x=y21*a11, color='black',linewidth=3.0,linestyle='--')
ax2.set_xlabel(r'$\gamma \sqrt{p_X p_Y}$', fontsize=24)
ax2.set_xlim(0,2.4)
ax2.set_ylabel(r'$\rho(\gamma)/\sqrt{p_X p_Y}$', fontsize=24)
ax2.tick_params(labelsize=16) 
ax2.legend(title='$p_X=p_Y=0.01$', framealpha=0.5, fontsize=16, title_fontsize=20,loc=1)
ax2.annotate('(b)', xy=(0, 1), xycoords='axes fraction', fontsize=24,
                xytext=(-25,25), textcoords='offset points',
                ha='right', va='top')

T=500
Nx=1000
Ny=50000
W1pro1= np.loadtxt('simpurenoise3.txt', delimiter=" ")
W1pro= np.loadtxt('simpurenoise3.txt', delimiter=" ")
import numpy as np
import matplotlib.pyplot as plt
from sympy import roots
from sympy import var
from sympy import re, im, I, E, symbols
import numpy as np
import sympy as sym
from math import sqrt
from sympy.abc import g

q=Nx/Ny
qU=T/Nx
qv=T/Ny

xB=[]
y2B=[]
yimgB=[]
yrealB=[]
for i in range (1, 600):
    a1=i*1-I*0.0001
    a1inot=i*1
    a13=a1**2*qU*qv
    a12=(qv*(1-qU)+qU*(1-qv))*a1
    a11=((1-qU)*(1-qv))-a1*qU*qv
    a10=qU*qv
    xB.append(a1inot)
    ysols=[]
    ysols1=[]
    a=roots(a13*g**3+a12*g**2+a11*g+a10,g)
    value=[im(j) for j in a if a[j]==int(1)]
    result = a.items()
    data = list(result)
    for i in range(len(data)):
        a1=complex(data[i][0])
        a1r=a1.real/(3.14)
        a1img=a1.imag/(3.14)
        ysols.append(a1img)
        ysols1.append(a1.real)
    yimgB.append(ysols)
    yrealB.append(ysols1)

print('done')
ydata=[]
for i in range (len(xB)):
    ydata.append(abs(yimgB[i][1]))
xB=np.array(xB)
a11=np.sqrt(qU*qv)
qx=qU
y1=(1+qU+2*np.sqrt(qU))/(qU*qv)
y2=(1+qU-2*np.sqrt(qU))/(qU*qv)
ydataB=np.array(ydata)
y11=math.sqrt(y1)
y21=math.sqrt(y2)
xB=np.array(xB)
xB1=np.sqrt(xB)
W1pro1=np.sqrt(W1pro)
ydataB=np.array(ydata)
ydataB1=np.multiply(xB1,ydata)
ax3.plot(xB1*a11,2*ydataB1/(a11), linewidth=3.0, color='#f781bf', label='Semi-Analytic')
ax3.hist(W1pro1*a11, histtype='bar', density=True, bins=200,  color = "#377eb8" ,label='Simulation')
ax3.axvline(x=y11*a11, color='black', linewidth=3.0, linestyle='--',label= 'Analytic bounds')
ax3.axvline(x=y21*a11, color='black',linewidth=3.0,linestyle='--')
ax3.set_xlabel(r'$\gamma \sqrt{p_X p_Y}$', fontsize=24)
ax3.set_ylabel(r'$\rho(\gamma)/\sqrt{p_X p_Y}$', fontsize=24)
ax3.tick_params(labelsize=16) 
ax3.legend(title='$p_X=0.5$\n$p_Y=0.01$', framealpha=0.5, fontsize=16, title_fontsize=20,loc=1)
ax3.annotate('(c)', xy=(0, 1), xycoords='axes fraction', fontsize=24,
                xytext=(-25,25), textcoords='offset points',
                ha='right', va='top')
ax3.set_xlim(0,2.4)

T=500
Nx=50000
Ny=100000
W1pro1= np.loadtxt('simpurenoise2.txt', delimiter=" ")
W1pro= np.loadtxt('simpurenoise2.txt', delimiter=" ")
import numpy as np
import matplotlib.pyplot as plt
from sympy import roots
from sympy import var
from sympy import re, im, I, E, symbols
import numpy as np
import sympy as sym
from math import sqrt
from sympy.abc import g

q=Nx/Ny
qU=T/Nx
qv=T/Ny

xB=[]
y2B=[]
yimgB=[]
yrealB=[]
for i in range (1500, 2600):
    a1=i*10-I*0.0001
    a1inot=i*10
    a13=a1**2*qU*qv
    a12=(qv*(1-qU)+qU*(1-qv))*a1
    a11=((1-qU)*(1-qv))-a1*qU*qv
    a10=qU*qv
    xB.append(a1inot)
    ysols=[]
    ysols1=[]
    a=roots(a13*g**3+a12*g**2+a11*g+a10,g)
    value=[im(j) for j in a if a[j]==int(1)]
    result = a.items()
    data = list(result)
    for i in range(len(data)):
        a1=complex(data[i][0])
        a1r=a1.real/(3.14)
        a1img=a1.imag/(3.14)
        ysols.append(a1img)
        ysols1.append(a1.real)
    yimgB.append(ysols)
    yrealB.append(ysols1)

print('done')
ydata=[]
for i in range (len(xB)):
    ydata.append(abs(yimgB[i][1]))
xB=np.array(xB)
a11=np.sqrt(qU*qv)
qx=qU
y1=(1+qU+qv+2*np.sqrt(qU+qv))/(qU*qv)
y2=(1+qU+qv-2*np.sqrt(qU+qv))/(qU*qv)
ydataB=np.array(ydata)
y11=math.sqrt(y1)
y21=math.sqrt(y2)
xB=np.array(xB)
xB1=np.sqrt(xB)
W1pro1=np.sqrt(W1pro)
ydataB=np.array(ydata)
ydataB1=np.multiply(xB1,ydata)
ax4.plot(xB1*a11,2*ydataB1/(a11), linewidth=3.0, color='#f781bf', label='Semi-Analytic')
ax4.hist(W1pro1*a11, histtype='bar', density=True, bins=200,  color = "#377eb8" ,label='Simulation')
ax4.axvline(x=y11*a11, color='black', linewidth=3.0, linestyle='--',label= 'Analytic bounds')
ax4.axvline(x=y21*a11, color='black',linewidth=3.0,linestyle='--')
ax4.set_xlabel(r'$\gamma \sqrt{p_X p_Y}$', fontsize=24)
ax4.set_ylabel(r'$\rho(\gamma)/\sqrt{p_X p_Y}$', fontsize=24)
ax4.tick_params(labelsize=16) 
ax4.legend(title='$p_X=0.01$\n$p_Y=0.005$', framealpha=0.5, fontsize=16, title_fontsize=20,loc=1)
ax4.annotate('(d)', xy=(0, 1), xycoords='axes fraction', fontsize=24,
                xytext=(-25,25), textcoords='offset points',
                ha='right', va='top')
ax4.set_xlim(0,2.4)
fig.tight_layout()
plt.savefig('purenoise.pdf',dpi=600)

plt.show()
# Out:
# done
# done
# done
# done

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
T=1000
Nx=800
Ny=800
P=np.random.normal(0,1,size=(T,Nx))
Pt=np.transpose(P)
A=np.matmul(P,Pt)
Qx=np.random.normal(0,1,size=(T,Ny))
Qxt=np.transpose(Qx)
A1=np.matmul(Qx,Qxt)
B=np.matmul(A,A1)
B1=np.multiply(B,1/(T*T))
w,v=np.linalg.eig(B1)


W1=w
for i in range(500):
    P=np.random.normal(0,1,size=(T,Nx))
    Pt=np.transpose(P)
    A=np.matmul(P,Pt)
    Qx=np.random.normal(0,1,size=(T,Ny))
    Qxt=np.transpose(Qx)
    A1=np.matmul(Qx,Qxt)
    B=np.matmul(A,A1)
    B1=np.multiply(B,1/(T*T))
    w,v=np.linalg.eig(B1)
    W2=np.hstack((W1, w))
    W1=W2
    W1pro=W1
plt.hist(W1, histtype='bar', density=True, bins=20, color = "skyblue")
print(len(W1))

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import roots
from sympy import var
from sympy import re, im, I, E, symbols
import numpy as np
import sympy as sym
from math import sqrt

from sympy.abc import g
T=1000
Nx=800
Ny=800
q=Nx/Ny
qU=T/Nx
qv=T/Ny

xB=[]
y2B=[]
yimgB=[]
yrealB=[]
plt.figure(figsize=(8.25, 7))
ivec=np.logspace(-5, 0.7, num=1000,base=100)
for i in range(len(ivec)):
    a1=ivec[i]-I*0.0001
    a1inot=ivec[i]
    a13=a1**2*qU*qv
    a12=(qv*(1-qU)+qU*(1-qv))*a1
    a11=((1-qU)*(1-qv))-a1*qU*qv
    a10=qU*qv
    xB.append(a1inot)
    ysols=[]
    ysols1=[]
    a=roots(a13*g**3+a12*g**2+a11*g+a10,g)
    value=[im(j) for j in a if a[j]==int(1)]
    result = a.items()
    data = list(result)
    for i in range(len(data)):
        a1=complex(data[i][0])
        a1r=a1.real/(3.14)
        a1img=a1.imag/(3.14)
        ysols.append(a1img)
        ysols1.append(a1.real)
    yimgB.append(ysols)
    yrealB.append(ysols1)

print('done')
ydata=[]
for i in range (len(xB)):
    ydata.append(abs(yimgB[i][1]))
xB=np.array(xB)
a11=np.sqrt(qU*qv)
qx=qU
y1=0
y2=y2=(8*qx**2 + 20*qx**3 - qx**4 + qx**(5/2)*(8 + qx)**(3/2))/(8*qx**4)
ydataB=np.array(ydata)
y11=np.sqrt(y1)
y21=np.sqrt(y2)
xB=np.array(xB)
xB1=np.sqrt(xB)
W1pro=W1pro[W1pro >0]
W1pro1=np.sqrt(W1pro)

ydataB=np.array(ydata)
ydataB1=np.multiply(xB1,ydata)
plt.plot(xB1*a11,2*ydataB1/(a11)*1.09, linewidth=3.0, color='#f781bf', label='Semi-Analytic')
plt.hist(W1pro1*a11, histtype='bar', density=True, bins=40,  color = "#377eb8" ,label='Simulation')
plt.axvline(x=y11*a11, color='black', linewidth=3.0, linestyle='--',label= 'Analytic bounds')
plt.axvline(x=y21*a11, color='black',linewidth=3.0,linestyle='--')
plt.xlabel(r'$\gamma /\sqrt{q_X q_Y}$', fontsize=24)
plt.ylabel(r'$\rho(\gamma)\sqrt{q_X q_Y}$', fontsize=24)
plt.tick_params(labelsize=16) 
plt.legend(title=r'$q_X=q_Y=0.8$', framealpha=0.5, fontsize=16, title_fontsize=20,loc=1)

plt.xlim(-0.02,3)
plt.ylim(0,2)

plt.tight_layout()
plt.savefig('purenoise2.png',dpi=600)
plt.show()
